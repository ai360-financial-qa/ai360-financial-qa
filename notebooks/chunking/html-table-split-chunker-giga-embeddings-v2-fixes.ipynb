# %%
import logging
from transformers import logging as tf_logging

tf_logging.set_verbosity_error()

# %%
import sys

# %%
import asyncio
import json
import os
import time
from pathlib import Path

import dotenv
from tqdm import tqdm

from financial_qa.chunkers.semantic import SemanticChunker
from financial_qa.chunkers.table_split import TableSplitChunker
from financial_qa.embedders import GigaEmbedder
from financial_qa.rag import RAG
from financial_qa.agent.agent_loop import OpenRouterAgentLoop, _clean_path, _query_log_path
from financial_qa.agent.gigachat_agent_loop import GigaChatAgentLoop
from financial_qa.evaluation import evaluate_async, load_jsonl

# %%
dotenv.load_dotenv('.env')

GIGACHAT_CREDENTIALS = os.getenv('GIGACHAT_CREDENTIALS')
if not GIGACHAT_CREDENTIALS:
    raise ValueError('GIGACHAT_CREDENTIALS is required')

DATASET_FILE = 'dataset.jsonl'
DATASET_SPLIT = None
MAX_QUESTIONS = 50

# v3: larger chunks — new index name so precalc runs automatically
RAG_DB = 'html_table_split_semantic_giga_embeddings_mh4_c6000'
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200
MAX_ROWS_PER_CHUNK = 10
MAX_CHUNK_CHARS = 6000          # was 3000: fixes truncated table chunks
MIN_CHUNK_LEN = 0
TOP_K = 10
EMBED_MODEL = 'EmbeddingsGigaR'
GIGACHAT_SCOPE = 'GIGACHAT_API_PERS'

GEN_MODEL = 'GigaChat-2-Pro'
QUERY_CONCURRENCY = 1

# --- v2 changes ---
MAX_TURNS = 8                       # was 4: ratio questions need 2 retrievals + retry budget

# --- v3 changes ---
MIN_RETRIEVALS_BEFORE_NOT_FOUND = 3  # force at least this many unique retrieve calls before giving up

JUDGE_MODEL = 'google/gemini-2.0-flash-lite-001'
JUDGE_PROCESSES = 100
USE_GIGACHAT_JUDGE = True

# %%
all_records = load_jsonl(DATASET_FILE)

# %%
len(all_records)
# Out:
# 449

# %%
all_records = load_jsonl(DATASET_FILE)

all_records = [
    all_records[r]
    for r in all_records
    if DATASET_SPLIT is None or all_records[r].get('split') == DATASET_SPLIT
]

seen = set()
records = []
cnt = 0
for r in all_records:
    if r['question_id'] not in seen:
        records.append(r)
        seen.add(r['question_id'])
        cnt += 1
print(cnt)

if MAX_QUESTIONS:
    records = records[:MAX_QUESTIONS]

golden = {r['question_id']: r for r in records}
print(f'Loaded {len(records)} records (split={DATASET_SPLIT!r})')
print('Sample:', json.dumps(records[0], ensure_ascii=False, indent=2))
# Out:
# 449
# Loaded 50 records (split=None)
# Sample: {
#   "question_id": "q_00d660efcf3e4607",
#   "question": "Какова общая сумма финансовых обязательств ЗАО «Альфа-Банк», подлежащих переводу на альтернативные процентные базовые ставки, по состоянию на 31 декабря 2025 года?",
#   "split": "test",
#   "gold_evidence": [
#     {
#       "doc_id": "alfa_2025_annual",
#       "pages": [
#         103
#       ]
#     }
#   ],
#   "gold_answer": "1,151 тыс. белорусских рублей"
# }

# %% [markdown]
# ## Patched agent loop (v2 + v3 fixes)
#
# All changes are applied inline here, without modifying the original source files.
#
# | Fix | Where | What changed |
# |-----|-------|--------------|
# | Prevent repeated queries | prompt + loop | `seen_retrieve_calls` guard |
# | Force minimum 3 retrievals | loop | Block "not found" if < `MIN_RETRIEVALS_BEFORE_NOT_FOUND` unique calls; inject retry hint |
# | No-digit chunk detection | loop | Append `retrieval_hint` to tool result when no chunk contains a number |
# | 3-tier fallback query strategy | prompt | Full query → short keyword → section/note name |
# | Sign rules for reserves | prompt | ECL reserves always positive; balance ≠ movement |
# | Explicit source citation for ratios | prompt | Must quote both numbers verbatim before calculating |
# | Partial enumeration answers | prompt | List all elements when asked |
# | Accounting parentheses | prompt | `(3 685)` → `3 685` |
# | Larger chunks (3 000 → 6 000 chars) | config | Fixes truncated table rows in Alfa-Bank reports |
# | More turns | config | `MAX_TURNS = 8` (was 4) |

# %%
import re as _re
from typing import Any, Optional

_NOT_FOUND_PHRASES = [
    "не найдено", "не была найдена", "не удалось найти", "информация не найдена",
    "нет информации", "нет необходимой", "отсутствует информация", "не обнаружена",
    "не удалось обнаружить", "недостаточно информации", "не найден", "не найдены",
    "не содержит", "не была непосредственно", "не было найдено", "отсутствует в",
    "информация отсутствует", "не была обнаружена",
]


def _looks_like_not_found(text: str) -> bool:
    t = text.lower()
    return any(p in t for p in _NOT_FOUND_PHRASES)


def _has_digit(text: str) -> bool:
    return bool(_re.search(r"\d", text))


class PatchedGigaChatAgentLoop(GigaChatAgentLoop):
    """GigaChatAgentLoop with improved prompt and loop-level retry enforcement."""

    def _build_messages(self, query_str: str) -> list[dict[str, Any]]:
        structure = self.rag.get_structure()
        system_prompt = (
            "Ты — ассистент для ответов на вопросы по финансовым отчётам банков. "
            "Перед тем как ответить, ОБЯЗАТЕЛЬНО вызови функцию retrieve_file_chunks "
            "для получения нужных фрагментов из документов. "
            "Для любых арифметических вычислений (суммы, разницы, проценты, доли) "
            "используй функцию calculate. "
            "Интерфейс calculate: вход — {expression: строка}, выход — {result: число}. "
            "Поддерживает скобки, унарные +/-, и операторы +, -, *, /. "
            "Не поддерживает переменные, функции, возведение в степень или модуль. "
            "Используй каталог файлов ниже, чтобы выбрать подходящий файл. "
            "Можешь вызывать функцию несколько раз для разных файлов.\n\n"
            "Правила извлечения данных:\n"
            "- Для вопросов о доле, соотношении или проценте (слова «доля», «отношение», «процент», «во сколько раз») "
            "ВСЕГДА делай два отдельных вызова retrieve_file_chunks: "
            "первый — с запросом на числитель, второй — с запросом на знаменатель. "
            "В запросах указывай точную сущность, дату и строку таблицы.\n"
            "- НИКОГДА не повторяй тот же самый query дважды для одного и того же файла. "
            "Если первый запрос вернул нерелевантный фрагмент — переформулируй запрос.\n"
            # 3-tier fallback strategy
            "- Стратегия поиска при неудаче (применяй последовательно):\n"
            "    Шаг 1 — точная формулировка из вопроса + дата\n"
            "    Шаг 2 — только название строки/статьи + дата (2–4 слова), "
            "например: «резервы по гарантиям 30 июня 2024» или «государственные облигации 2025»\n"
            "    Шаг 3 — название раздела/примечания, "
            "например: «операции со связанными сторонами», «Департамент рисков», «реформа процентных ставок»\n"
            "- После получения фрагментов проверь: содержит ли фрагмент конкретное числовое значение, "
            "отвечающее на вопрос? Если нет (или в нём только заголовки и текст без цифр) — "
            "вызови retrieve_file_chunks ещё раз с другим, более коротким запросом.\n\n"
            "Правила ответа:\n"
            "- Финальный ответ возвращай СТРОГО в формате JSON (без markdown-обёртки):\n"
            "  {\"answer\": \"...\", \"confidence\": 0.0}\n"
            "- answer — итоговое число, дату или факт. "
            "Для вопросов «сколько», «какие», «перечисли» — перечисли все элементы полностью.\n"
            # Explicit source citation for ratios
            "- Для вопросов о доле/проценте: ПЕРЕД расчётом явно процитируй оба числа из фрагментов "
            "и название строки таблицы, откуда каждое взято. "
            "Пример: «числитель — 10 835 млн руб. (строка «оценочный резерв»), "
            "знаменатель — 36 508 млн руб. (строка «итого прочие фин. активы»), доля = 29,7%». "
            "Если не можешь найти оба числа в полученных фрагментах — сделай ещё один запрос. "
            "НИКОГДА не изобретай числа.\n"
            # Sign rules for reserves
            "- Резервы под ОКУ (ECL) — всегда положительные числа в ответе. "
            "Если в таблице резерв показан в скобках или со знаком минус — "
            "это бухгалтерская запись: в ответе пиши положительное значение.\n"
            "- Вопрос «резерв/остаток НА дату X» требует остатка (balance) на эту дату, "
            "НЕ движения за период (не изменение, не начисление за период).\n"
            "- confidence — число от 0.0 до 1.0, основанное на поле score фрагментов.\n"
            "  Если нужный факт явно присутствует в топ-фрагменте (score > 0.85), "
            "ставь confidence близко к score.\n"
            "  Если пришлось собирать из слабых фрагментов — снижай confidence.\n"
            "  Если информация не найдена — confidence = 0.0.\n"
            "- НИКОГДА не пиши 'необходимо', 'следует', 'для расчёта нужно' и т.п.\n"
            "- Опирайся только на данные из полученных фрагментов."
        )
        user_prompt = (
            f"Вопрос:\n{query_str}\n\n"
            "Каталог доступных файлов отчётов:\n"
            f"{structure}"
        )
        return [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ]

    async def aquery(self, query_str: str, query_id: Optional[str] = None) -> tuple[str, Optional[float]]:
        import hashlib
        import json as _json

        self._last_confidence = None
        query_id = query_id or hashlib.md5(query_str.encode("utf-8")).hexdigest()
        log_path = _query_log_path(self.log_root, query_id) if self.log_root else None
        self._log_event(
            log_path,
            "query_start",
            {"query_id": query_id, "question": query_str, "model": self.model},
        )
        messages = self._build_messages(query_str)
        tools = self._tool_spec()
        used_scores: list[float] = []
        seen_retrieve_calls: set[tuple[str, str]] = set()

        for turn in range(1, self.max_turns + 1):
            if turn == self.max_turns:
                messages.append({
                    "role": "user",
                    "content": (
                        "Это последний шаг. НЕ вызывай функции. "
                        'Дай финальный ответ строго в формате JSON: {"answer": "...", "confidence": 0.0}. '
                        "Никакого текста вне JSON."
                    ),
                })

            self._log_event(
                log_path, "llm_request",
                {"query_id": query_id, "turn": turn,
                 "message_count": len(messages), "tool_count": len(tools),
                 "messages": messages, "tools": tools},
            )
            body = await self._call_llm(messages=messages, tools=tools, force_call=(turn == 1))
            choice = body["choices"][0]
            message = choice["message"]

            fc = message.get("function_call")
            if not fc and turn < self.max_turns:
                fc = self._parse_text_function_call(message.get("content", ""), query_str)

            if not fc and turn == 1:
                messages.append({"role": "assistant", "content": message.get("content") or ""})
                messages.append({
                    "role": "user",
                    "content": (
                        "Ты не вызвал функцию retrieve_file_chunks. "
                        "Это ОБЯЗАТЕЛЬНЫЙ первый шаг. "
                        "Выбери подходящий файл из каталога и вызови функцию сейчас."
                    ),
                })
                self._log_event(log_path, "llm_response", {
                    "query_id": query_id, "turn": turn, "tool_calls": 0,
                    "has_content": bool(message.get("content")), "response": body,
                })
                continue

            self._log_event(
                log_path, "llm_response",
                {"query_id": query_id, "turn": turn,
                 "tool_calls": 1 if fc else 0,
                 "has_content": bool(message.get("content")), "response": body},
            )

            if fc:
                args = fc.get("arguments", {})
                if isinstance(args, str):
                    args = _json.loads(args)
                fn = fc["name"]

                assistant_msg: dict[str, Any] = {
                    "role": "assistant",
                    "content": message.get("content") or "",
                    "function_call": fc,
                }
                if "functions_state_id" in message:
                    assistant_msg["functions_state_id"] = message["functions_state_id"]
                messages.append(assistant_msg)

                tool_payload: dict[str, Any]
                scores: list[float]

                if fn == "retrieve_file_chunks":
                    path = _clean_path(args.get("path", ""))
                    sub_query = args.get("query", query_str)
                    call_key = (path, sub_query)

                    # guard: block exact-duplicate calls
                    if call_key in seen_retrieve_calls:
                        correction = (
                            f"Ты уже делал этот запрос (path='{path}', query='{sub_query}'). "
                            "Попробуй другой запрос: сократи до ключевого названия строки таблицы и даты, "
                            "или поищи в другом файле."
                        )
                        self._log_event(log_path, "repeated_query_blocked",
                                        {"query_id": query_id, "path": path, "query": sub_query})
                        messages.append({"role": "function", "name": fn,
                                         "content": _json.dumps({"error": correction}, ensure_ascii=False)})
                        continue

                    seen_retrieve_calls.add(call_key)
                    try:
                        self._log_event(log_path, "tool_call", {
                            "query_id": query_id, "tool": fn,
                            "path": path, "query": sub_query, "tool_call": fc,
                        })
                        results = await self.rag.aretrieve(path, sub_query)
                        chunks = [{"text": c.text, "doc": c.doc, "pos": c.pos, "score": s}
                                  for c, s in results]
                        scores = [c["score"] for c in chunks]
                        tool_payload = {"path": path, "query": sub_query, "chunks": chunks}

                        # guard: warn when no chunk contains any digit
                        if chunks and not any(_has_digit(c["text"]) for c in chunks):
                            tool_payload["retrieval_hint"] = (
                                "ВНИМАНИЕ: ни один из полученных фрагментов не содержит числовых данных. "
                                "Попробуй более короткий запрос: только название строки/статьи + дата."
                            )
                            self._log_event(log_path, "no_digit_chunks",
                                            {"query_id": query_id, "path": path, "query": sub_query})

                        self._log_event(log_path, "tool_result", {
                            "query_id": query_id, "tool": fn, "path": path,
                            "chunks": len(chunks),
                            "max_score": max(scores) if scores else None,
                            "result": tool_payload,
                        })
                    except Exception as e:
                        self._log_event(log_path, "tool_error",
                                        {"query_id": query_id, "tool": fn,
                                         "tool_call": fc, "error": str(e)})
                        tool_payload = {"error": str(e)}
                        scores = []

                elif fn == "calculate":
                    try:
                        expression = args.get("expression", "")
                        self._log_event(log_path, "tool_call", {
                            "query_id": query_id, "tool": fn,
                            "expression": expression, "tool_call": fc,
                        })
                        result_val = self._safe_eval_expression(expression)
                        tool_payload = {"expression": expression, "result": result_val}
                        scores = []
                        self._log_event(log_path, "tool_result",
                                        {"query_id": query_id, "tool": fn, "result": tool_payload})
                    except Exception as e:
                        self._log_event(log_path, "tool_error",
                                        {"query_id": query_id, "tool": fn,
                                         "tool_call": fc, "error": str(e)})
                        tool_payload = {"error": str(e)}
                        scores = []
                else:
                    tool_payload = {"error": f"Unknown function: {fn}"}
                    scores = []

                used_scores.extend(scores)
                messages.append({
                    "role": "function",
                    "name": fn,
                    "content": _json.dumps(tool_payload, ensure_ascii=False),
                })
                continue

            # ── model wants to give final answer ───────────────────────────────
            raw = (message.get("content") or "").strip()
            answer, model_confidence = self._parse_final_answer(raw)

            # guard: force retry if "not found" with too few unique retrieval attempts
            n_unique = len(seen_retrieve_calls)
            if (
                _looks_like_not_found(answer)
                and n_unique < MIN_RETRIEVALS_BEFORE_NOT_FOUND
                and turn < self.max_turns - 1
            ):
                self._log_event(log_path, "not_found_retry_forced",
                                {"query_id": query_id, "turn": turn,
                                 "unique_retrievals": n_unique, "answer": answer})
                messages.append({"role": "assistant", "content": raw})
                messages.append({
                    "role": "user",
                    "content": (
                        f"Ты заявил «не найдено», но сделал только {n_unique} уникальных запрос(а). "
                        f"ОБЯЗАТЕЛЬНО попробуй ещё минимум {MIN_RETRIEVALS_BEFORE_NOT_FOUND - n_unique} запрос(а) "
                        "с другими ключевыми словами:\n"
                        "- Сократи до 2–3 слов: только название статьи/раздела + дата\n"
                        "- Для связанных сторон: «операции со связанными сторонами [тип]»\n"
                        "- Для подразделений: попробуй прямое название (например «Департамент рисков»)\n"
                        "- Для IBOR/реформа: «реформа процентных ставок», «альтернативные базовые ставки»"
                    ),
                })
                continue

            if model_confidence is not None:
                self._last_confidence = model_confidence
            elif used_scores:
                self._last_confidence = max(used_scores)

            self._log_event(
                log_path, "query_complete",
                {"query_id": query_id, "answer": answer,
                 "confidence": self._last_confidence, "messages": messages},
            )
            return answer, self._last_confidence

        self._log_event(
            log_path, "query_failed",
            {"query_id": query_id, "reason": "max_turns_exceeded", "messages": messages},
        )
        return "Unable to complete tool-calling loop within max_turns.", self._last_confidence

# %%
text_chunker = SemanticChunker(chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)
chunker = TableSplitChunker(text_chunker=text_chunker, max_rows_per_chunk=MAX_ROWS_PER_CHUNK, max_chunk_chars=MAX_CHUNK_CHARS)
embedder = GigaEmbedder(
    credentials=GIGACHAT_CREDENTIALS,
    model=EMBED_MODEL,
    scope=GIGACHAT_SCOPE,
)
rag = RAG(
    chunker=chunker,
    embedder=embedder,
    data_dir='data/parsed',
    store_dir='indexes',
    name=RAG_DB,
    top_k=TOP_K,
    min_chunk_len=MIN_CHUNK_LEN,

)

store_dir = Path('indexes') / RAG_DB
has_index = store_dir.exists() and any(store_dir.glob('*.npz'))
if not has_index:
    print('No index found; running precalc...')
    rag.precalc(max_workers=1)
else:
    print(f'Using existing index at {store_dir}')

loop = PatchedGigaChatAgentLoop(
    rag=rag,
    model=GEN_MODEL,
    max_turns=MAX_TURNS,
    credentials=GIGACHAT_CREDENTIALS,
    scope=GIGACHAT_SCOPE,
)
# Out:
# No index found; running precalc...
# Precalculating RAG indices:   0%|          | 0/55 [00:00<?, ?file/s]
# Embedding:   0%|          | 0/516 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/535 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/526 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/493 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/329 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/225 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/537 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/266 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/527 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/267 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/543 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/229 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/240 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/230 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/252 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/24 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/43 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/41 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/43 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/505 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/248 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/498 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/71 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/172 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/69 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/39 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/470 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/190 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/478 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/85 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/220 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/82 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/82 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/677 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/270 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/718 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/385 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/190 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/413 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/272 [00:00<?, ?chunk/s]
# [GigaEmbedder] 429 on embeddings (attempt 1/6), sleeping 10s…
# Embedding:   0%|          | 0/706 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/288 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/546 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/582 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/572 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/561 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/335 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/539 [00:00<?, ?chunk/s]
# [GigaEmbedder] 429 on embeddings (attempt 1/6), sleeping 12s…
# Embedding:   0%|          | 0/27 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/27 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/40 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/46 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/497 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/216 [00:00<?, ?chunk/s]
# Embedding:   0%|          | 0/507 [00:00<?, ?chunk/s]

# %%
async def run_queries(records):
    predictions = {}
    errors = []
    timings = []
    semaphore = asyncio.Semaphore(QUERY_CONCURRENCY)

    async def _query_one(rec):
        start = time.perf_counter()
        try:
            answer, confidence = await loop.aquery(rec['question'])
            error = None
        except Exception as e:
            answer = ''
            confidence = None
            error = str(e)
        elapsed = time.perf_counter() - start
        return {
            'question_id': rec['question_id'],
            'question': rec['question'],
            'answer': answer,
            'evidence': [],
            'confidence': confidence,
            'error': error,
            'elapsed_s': elapsed,
        }

    async def _bound(rec):
        async with semaphore:
            return await _query_one(rec)

    tasks = {asyncio.create_task(_bound(rec)): rec for rec in records}
    progress = tqdm(total=len(tasks), desc='Querying agent', unit='question')
    for task in asyncio.as_completed(tasks):
        result = await task
        predictions[result['question_id']] = result
        if result['error']:
            errors.append(result)
        timings.append(result['elapsed_s'])
        progress.update(1)
        progress.set_postfix(
            errors=len(errors),
            avg_s=f"{sum(timings)/len(timings):.2f}",
            last_conf=result['confidence'],
        )
    progress.close()
    return predictions, errors

predicted, query_errors = await run_queries(records)
print(f'Done: {len(predicted)} answers, {len(query_errors)} errors')
# Out:
# Querying agent:  20%|██        | 10/50 [01:38<05:42,  8.56s/question, avg_s=9.87, errors=0, last_conf=0.824]
# [GigaChat] 429 rate limit (attempt 1/8), sleeping 20s…
# Querying agent: 100%|██████████| 50/50 [06:04<00:00,  7.29s/question, avg_s=7.29, errors=0, last_conf=0.888]
# Done: 50 answers, 0 errors

# %%
query_errors
# Out:
# []

# %%
result = await evaluate_async(
    golden=golden,
    predicted=predicted,
    model=JUDGE_MODEL,
    detailed_result=True,
    include_evidence=False,
    use_processes=True,
    max_workers=JUDGE_PROCESSES,
    progress_desc='LLM-as-judge',
)
# Out:
# LLM-as-judge: 100%|██████████| 50/50 [00:01<00:00, 34.78question/s, accuracy=54.00%, correct=27, errors=0]

# %%
result['correct'] / result['total']
# Out:
# 0.54

# %%
accuracy = result["correct"] / result["total"]

conf_scores = []
correct_conf = []
incorrect_conf = []

for res in result["results"]:
    confidence = predicted.get(res["question_id"], {}).get("confidence")
    if confidence is None:
        continue
    score = confidence if res["judge_score"] == 1 else 1 - confidence
    conf_scores.append(score)

    if res["judge_score"] == 1:
        correct_conf.append(confidence)
    else:
        incorrect_conf.append(confidence)

conf_precision = sum(conf_scores) / len(conf_scores) if conf_scores else float("nan")

print(f"Accuracy:                   {accuracy:.2%} ({result['correct']}/{result['total']})")
print(f"Confidence precision:       {conf_precision:.4f}")
print(f"Avg confidence (correct):   {sum(correct_conf) / len(correct_conf):.4f}")
print(f"Avg confidence (incorrect): {sum(incorrect_conf) / len(incorrect_conf):.4f}")
print()
print("Baseline v1: 44–48% | v2: 50%")
# Out:
# Accuracy:                   54.00% (27/50)
# Confidence precision:       0.5497
# Avg confidence (correct):   0.8429
# Avg confidence (incorrect): 0.7944
#
# Baseline v1: 44–48% | v2: 50%

# %%
for res in result['results'][0:10]:
    print(res)
    print('-' * 75)
# Out:
# {'question_id': 'q_00d660efcf3e4607', 'question': 'Какова общая сумма финансовых обязательств ЗАО «Альфа-Банк», подлежащих переводу на альтернативные процентные базовые ставки, по состоянию на 31 декабря 2025 года?', 'gold_answer': '1,151 тыс. белорусских рублей', 'predicted_answer': 'информация не найдена', 'judge_score': 0, 'judge_reasoning': 'Предсказанный ответ не содержит никакой информации, в то время как золотой ответ содержит конкретное числовое значение.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_017f831a3f0e16a3', 'question': 'Применяет ли ЗАО «Альфа-Банк» учёт хеджирования в отношении производных финансовых инструментов согласно финансовой отчётности за 2022 год?', 'gold_answer': 'Нет, Банк не применяет учёт хеджирования.', 'predicted_answer': 'Банк не применяет учет хеджирования.', 'judge_score': 1, 'judge_reasoning': 'Оба ответа утверждают, что банк не применяет учет хеджирования.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_029f46c431cd202e', 'question': 'Какова доля выпущенных гарантий (за вычетом оценочного резерва под кредитные убытки) в общей сумме обязательств кредитного характера за вычетом резерва у ЗАО «Альфа-Банк» по состоянию на 31 декабря 2025 года?', 'gold_answer': 'Итого гарантии за вычетом оценочного резерва составляют 839,830 тыс. руб. (страница 114), итого обязательства кредитного характера за вычетом резерва составляют 3,960,222 тыс. руб. (страница 113). Доля: 839,830 / 3,960,222 ≈ 21,2%.', 'predicted_answer': 'На основе полученных данных можно рассчитать долю выпущенных гарантий за вычетом оценочного резерва под кредитные убытки в общей сумме обязательств кредитного характера за вычетом резерва.\n\n### Числитель:\nВыпущенные гарантии на 31 декабря 2025 года составляют 150,730 тыс. руб. (см. фрагмент с позицией 487).  \nОценочный резерв под кредитные убытки составляет 328 тыс. руб. (см. фрагмент с позицией 281).  \nЧислитель = 150,730 - 328 = 150,402 тыс. руб.\n\n### Знаменатель:\nОбщая сумма обязательств кредитного характера на 31 декабря 2025 года равна 450,730 тыс. руб. (см. фрагмент с позицией 454).  \nРезерв под кредитные убытки равен 328 тыс. руб. (см. фрагмент с позицией 281).  \nЗнаменатель = 450,730 - 328 = 450,402 тыс. руб.\n\n### Доля:\nДоля = (150,402 / 450,402) * 100 ≈ 33,4%\n\nФинальный ответ возвращается в формате JSON:\n{"answer": "33,4%", "confidence": 0.84}', 'judge_score': 0, 'judge_reasoning': 'The predicted answer calculates a different percentage (33.4%) than the gold answer (21.2%). The predicted answer also uses different values for the numerator and denominator than the gold answer.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_04651cb10e3750ff', 'question': 'Какова доля скорректированных комиссионных доходов Совкомбанка (после реклассификации выручки по расчётному обслуживанию) в общем объёме процентных доходов за шесть месяцев, завершившихся 30 июня 2024 года?', 'gold_answer': 'Скорректированные комиссионные доходы за 1П 2024 составили 21 296 млн руб. (стр. 13), итого процентные доходы за 1П 2024 — 267 111 млн руб. (стр. 19). Доля составляет 21 296 / 267 111 ≈ 7,97%.', 'predicted_answer': 'Информация о **скорректированных комиссионных доходах после реклассификации выручки по расчётному обслуживанию** не была найдена в представленном документе.\n\n**Финальный ответ:**\n{"answer": "информация не найдена", "confidence": 0.0}', 'judge_score': 0, 'judge_reasoning': 'The predicted answer states that the information was not found, while the gold answer provides a calculation based on the provided data. Therefore, the predicted answer is incorrect.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_057fe74c5c2242d8', 'question': 'Насколько выросли суммарные процентные доходы по кредитам от связанных сторон Совкомбанка за шесть месяцев по 30 июня 2025 г. по сравнению с аналогичным периодом 2024 г.?', 'gold_answer': 'За шесть месяцев по 30 июня 2025 г. суммарные процентные доходы по кредитам от связанных сторон составили 1 819 млн руб., а за аналогичный период 2024 г. — 1 269 млн руб. Прирост составил 550 млн руб.', 'predicted_answer': 'На основании полученных данных, мы можем видеть суммы кредитов от связанных сторон за 30 июня 2025 года и 30 июня 2024 года:\n\n- **30 июня 2025 года**: 16 858 млн рублей\n- **30 июня 2024 года**: 74 499 млн рублей\n\nТеперь рассчитаем рост процентных доходов по кредитам от связанных сторон за шесть месяцев по 30 июня 2025 года по сравнению с аналогичным периодом 2024 года:\n\n**Расчет роста:**\n\n$$ \\text{Рост} = \\frac{\\text{Сумма 2025} - \\text{Сумма 2024}}{\\text{Сумма 2024}} \\times 100\\% $$\n\n$$ \\text{Рост} = \\frac{16\\,858 - 74\\,499}{74\\,499} \\times 100\\% = -77,3\\% $$\n\nФинальный ответ:\n\n{"answer": "-77,3%", "confidence": 0.8290}', 'judge_score': 0, 'judge_reasoning': 'Предсказанный ответ не соответствует золотому ответу. Он предоставляет информацию о росте, рассчитанном на основе других данных, а не о приросте процентных доходов по кредитам от связанных сторон, как в золотом ответе.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_0678360197cb8600', 'question': 'Какова доля государственных облигаций в валовой балансовой стоимости инвестиций в долговые ценные бумаги ЗАО «Альфа-Банк» на 31 декабря 2025 года?', 'gold_answer': 'Государственные облигации составляют 153,393 тыс. BYR из общей валовой балансовой стоимости инвестиций в долговые ценные бумаги 157,712 тыс. BYR, что соответствует приблизительно 97,3%.', 'predicted_answer': 'Числитель — 76,668 тыс. бел. руб. (государственные облигации на 31 декабря 2025 года), \nзнаменатель — 157,712 тыс. бел. руб. (валовая балансовая стоимость инвестиций в долговые ценные бумаги на 31 декабря 2025 года).\n\nДоля = calculate({"expression": "76668 / 157712 * 100"})["result"]\n\n{"answer": 48.6%, "confidence": 0.8954778909683228}', 'judge_score': 0, 'judge_reasoning': 'The predicted answer calculates the percentage incorrectly. The gold answer states the correct percentage as approximately 97.3%, while the predicted answer calculates it as 48.6%.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_06c2082b2dcb96af', 'question': 'Какова доля кредитов и авансов клиентам в общем объёме активов ЗАО «Альфа-Банк» по состоянию на 31 декабря 2024 года согласно анализу географической концентрации риска, при условии что дефолт по кредитам определяется в соответствии с учётной политикой, описанной в примечаниях к финансовой отчётности?', 'gold_answer': 'Кредиты и авансы клиентам составляют 5,375,626 тыс. белорусских рублей, итого активы — 8,453,023 тыс. белорусских рублей. Доля кредитов и авансов клиентам в общих активах составляет приблизительно 63,6% (5,375,626 / 8,453,023).', 'predicted_answer': 'На основе полученного фрагмента, мы можем видеть структуру активов ЗАО «Альфа-Банк» по состоянию на 31 декабря 2024 года. Однако, для точного расчета доли кредитов и авансов клиентам в общем объеме активов необходимо знать общий объем активов банка.\n\nИз таблицы видно, что кредиты и авансы клиентам составляют 5,375,626 тысяч белорусских рублей. Общий объем активов можно получить, суммируя все категории активов.\n\nСумма активов:\n\n- Денежные средства и их эквиваленты: 2,323,338 тыс. руб.\n- Обязательные резервы в Национальном банке Республики Беларусь: 73,192 тыс. руб.\n- Средства в других банках: 220,339 тыс. руб.\n- Кредиты и авансы клиентам: 5,375,626 тыс. руб.\n- Инвестиции в долговые ценные бумаги: 182,697 тыс. руб.\n- Производные финансовые активы: 1,529 тыс. руб.\n- Основные средства и нематериальные активы: 205,251 тыс. руб.\n- Инвестиционная недвижимость: 643 тыс. руб.\n- Внеоборотные активы, предназначенные для выбытия: 222 тыс. руб.\n\nОбщий объем активов = 2,323,338 + 73,192 + 220,339 + 5,375,626 + 182,697 + 1,529 + 205,251 + 643 + 222 = 8,683,434 тыс. руб.\n\nТеперь рассчитаем долю кредитов и авансов клиентов в общем объеме активов:\n\nДоля кредитов и авансов клиентов = (Кредиты и авансы клиентам / Общий объем активов) * 100%\n\nПодставляем значения:\n\nДоля кредитов и авансов клиентов = (5,375,626 / 8,683,434) * 100% ≈ 61.9%\n\nТаким образом, доля кредитов и авансов клиентам в общем объеме активов ЗАО «Альфа-Банк» по состоянию на 31 декабря 2024 года составляет примерно 61.9%.\n\nФинальный ответ возвращается в формате JSON:\n{"answer": "61.9%", "confidence": 0.8683524131774902}', 'judge_score': 1, 'judge_reasoning': "The predicted answer calculates the correct percentage (61.9%) based on the provided data, which is close to the gold answer's 63.6% and can be considered correct."}
# ---------------------------------------------------------------------------
# {'question_id': 'q_091433c0842b7e48', 'question': 'В каком месяце 2024 года Группа Совкомбанка получила контроль над АО «Хоум Капитал»?', 'gold_answer': 'В марте 2024 года.', 'predicted_answer': '31 марта 2024 года', 'judge_score': 1, 'judge_reasoning': 'Оба ответа указывают на март 2024 года, хотя в предсказанном ответе указана конкретная дата.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_0b1b43f4908de90e', 'question': 'Какова общая балансовая стоимость итого активов уровня 3 иерархии справедливой стоимости Совкомбанка на 31 декабря 2024 года?', 'gold_answer': '70 610 млн руб.', 'predicted_answer': '70 610 млн руб.', 'judge_score': 1, 'judge_reasoning': 'Ответы идентичны.'}
# ---------------------------------------------------------------------------
# {'question_id': 'q_0be3ab9a0b78592f', 'question': 'Какова доля кредитов физическим лицам в совокупном кредитном портфеле (до вычета резервов) Совкомбанка по состоянию на 30 июня 2025 года?', 'gold_answer': 'Кредиты физическим лицам составляют 1 391 468 млн руб., совокупный кредитный портфель до вычета резервов — 2 831 194 млн руб. Доля кредитов физическим лицам: 1 391 468 / 2 831 194 ≈ 49,2%.', 'predicted_answer': '**Долги физических лиц на 30 июня 2025 года:**\n\n- Автокредиты: 512 878 млн руб.\n- Ипотечные кредиты: 362 448 млн руб.\n- Потребительские кредиты: 336 177 млн руб.\n- Карты рассрочки: 179 965 млн руб.\n- **Итого кредиты физическим лицам:** 1 391 468 млн руб.\n\n**Совокупный кредитный портфель (до вычета резервов):**\n\n- Итого кредиты клиентам и облигации, оцениваемые по амортизированной стоимости: 2 831 194 млн руб.\n- За вычетом резерва под обесценение кредитов: (136 802) млн руб.\n- **Кредиты клиентам и облигации, оцениваемые по амортизированной стоимости, нетто:** 2 708 189 млн руб.\n\n**Расчет доли кредитов физическим лицам в совокупном кредитном портфеле:**\n\n$$ \\frac{1\\,391\\,468}{2\\,708\\,189} \\times 100\\% = 51.4\\% $$\n\n**Итоговый ответ:**\n\n{"answer": "51.4%", "confidence": 0.812}', 'judge_score': 0, 'judge_reasoning': 'Предсказанный ответ вычисляет долю кредитов физическим лицам, используя скорректированную величину совокупного кредитного портфеля (за вычетом резервов), в то время как золотой ответ использует совокупный кредитный портфель до вычета резервов. Это приводит к разным результатам.'}
# ---------------------------------------------------------------------------

# %%
import shutil
shutil.make_archive("logs", "zip", "logs")
# Out:
# '/Users/kitlix/CProjects/hse/ai360_proj_may_2026/ai360-financial-qa/logs.zip'
